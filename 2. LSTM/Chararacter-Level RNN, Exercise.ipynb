# %% [markdown]
# # Character-Level LSTM in PyTorch
#
# In this notebook, I'll construct a character-level LSTM with PyTorch. The network will train character by character on some text, then generate new text character by character. As an example, I will train on Anna Karenina. **This model will be able to generate new text based on the text from the book!**
#
# This network is based off of Andrej Karpathy's [post on RNNs](http://karpathy.github.io/2015/05/21/rnn-effectiveness/) and [implementation in Torch](https://github.com/karpathy/char-rnn). Below is the general architecture of the character-wise RNN.
#
# <img src="assets/charseq.jpeg" width="500">

# %% [markdown]
# First let's load in our required resources for data loading and model creation.

# %%
import numpy as np
import torch
from torch import nn
import torch.nn.functional as F

# %% [markdown]
# ## Load in Data
#
# Then, we'll load the Anna Karenina text file and convert it into integers for our network to use.
#
# ### Tokenization
#
# In the second cell, below, I'm creating a couple **dictionaries** to convert the characters to and from integers. Encoding the characters as integers makes it easier to use as input in the network.

# %%
# open text file and read in data as `text`
with open('data/anna.txt', 'r') as f:
    text = f.read()

# %% [markdown]
# Now we have the text, encode it as integers.

# %%
# encode the text and map each character to an integer and vice versa

# we create two dictonaries:
# 1. int2char, which maps integers to characters
# 2. char2int, which maps characters to unique integers
chars = tuple(set(text))
int2char = dict(enumerate(chars))
char2int = {ch: ii for ii, ch in int2char.items()}
encoded = np.array([char2int[ch] for ch in text])

# %% [markdown]
# Let's check out the first 100 characters, make sure everything is peachy. According to the [American Book Review](http://americanbookreview.org/100bestlines.asp), this is the 6th best first line of a book ever.

# %%
text[:100]
# Out:
# 'Chapter 1\n\n\nHappy families are all alike; every unhappy family is unhappy in its own\nway.\n\nEverythin'

# %% [markdown]
# And we can see those same characters encoded as integers.

# %%
encoded[:100]
# Out:
# array([41, 28,  2, 69, 80, 42, 82, 53, 59, 32, 32, 32,  4,  2, 69, 69, 46,
#        53, 24,  2, 71, 36, 54, 36, 42, 72, 53,  2, 82, 42, 53,  2, 54, 54,
#        53,  2, 54, 36,  0, 42, 29, 53, 42, 75, 42, 82, 46, 53, 17, 70, 28,
#         2, 69, 69, 46, 53, 24,  2, 71, 36, 54, 46, 53, 36, 72, 53, 17, 70,
#        28,  2, 69, 69, 46, 53, 36, 70, 53, 36, 80, 72, 53, 20, 62, 70, 32,
#        62,  2, 46, 43, 32, 32, 63, 75, 42, 82, 46, 80, 28, 36, 70])

# %% [markdown]
# ## Pre-processing the data
#
# As you can see in our char-RNN image above, our LSTM expects an input that is **one-hot encoded** meaning that each character is converted into an intgere (via our created dictionary) and *then* converted into a column vector where only it's corresponsing integer index will have the value of 1 and the rest of the vector will be filled with 0's. Since we're one-hot encoding the data, let's make a function to do that!

# %%
def one_hot_encode(arr, n_labels):
    
    # Initialize the the encoded array
    one_hot = np.zeros((np.multiply(*arr.shape), n_labels), dtype=np.float32)
    
    # Fill the appropriate elements with ones
    one_hot[np.arange(one_hot.shape[0]), arr.flatten()] = 1.
    
    # Finally reshape it to get back to the original array
    one_hot = one_hot.reshape((*arr.shape, n_labels))
    
    return one_hot

# %% [markdown]
# ## Making training mini-batches
#
#
# To train on this data, we also want to create mini-batches for training. Remember that we want our batches to be multiple sequences of some desired number of sequence steps. Considering a simple example, our batches would look like this:
#
# <img src="assets/sequence_batching@1x.png" width=500px>
#
#
# <br>
#
# In this example, we'll take the encoded characters (passed in as the `arr` parameter) and split them into multiple sequences, given by `n_seqs` (also refered to as "batch size" in other places). Each of those sequences will be `n_steps` long.
#
# ### Creating Batches
#
# **1. The first thing we need to do is discard some of the text so we only have completely full batches. **
#
# Each batch contains $N \times M$ characters, where $N$ is the batch size (the number of sequences) and $M$ is the number of steps. Then, to get the total number of batches, $K$, we can make from the array `arr`, you divide the length of `arr` by the number of characters per batch. Once you know the number of batches, you can get the total number of characters to keep from `arr`, $N * M * K$.
#
# **2. After that, we need to split `arr` into $N$ sequences. **
#
# You can do this using `arr.reshape(size)` where `size` is a tuple containing the dimensions sizes of the reshaped array. We know we want $N$ sequences, so let's make that the size of the first dimension. For the second dimension, you can use `-1` as a placeholder in the size, it'll fill up the array with the appropriate data for you. After this, you should have an array that is $N \times (M * K)$.
#
# **3. Now that we have this array, we can iterate through it to get our batches. **
#
# The idea is each batch is a $N \times M$ window on the $N \times (M * K)$ array. For each subsequent batch, the window moves over by `n_steps`. We also want to create both the input and target arrays. Remember that the targets are the inputs shifted over one character. The way I like to do this window is use `range` to take steps of size `n_steps` from $0$ to `arr.shape[1]`, the total number of steps in each sequence. That way, the integers you get from `range` always point to the start of a batch, and each window is `n_steps` wide.
#
# > **TODO:** Write the code for creating batches in the function below. The exercises in this notebook _will not be easy_. I've provided a notebook with solutions alongside this notebook. If you get stuck, checkout the solutions. The most important thing is that you don't copy and paste the code into here, **type out the solution code yourself.**

# %%
def get_batches(arr, n_seqs, n_steps):
    '''Create a generator that returns batches of size
       n_seqs x n_steps from arr.
       
       Arguments
       ---------
       arr: Array you want to make batches from
       n_seqs: Batch size, the number of sequences per batch
       n_steps: Number of sequence steps per batch
    '''
#     print(len(arr))
    # Get the number of characters per batch
    batch_size = n_seqs * n_steps
#     print(batch_size)
    ## TODO: Get the number of batches we can make
    n_batches = len(arr)//batch_size
#     print(n_batches)
    ## TODO: Keep only enough characters to make full batches
    arr = arr[:n_seqs*n_steps*n_batches]
#     print(len(arr))
    # TODO: Reshape into batch_size rows
    arr = arr.reshape((n_seqs,-1))
    
    # TODO: Make batches
    for n in range(0, arr.shape[1], n_steps):
        # The features
        x = arr[:,n:n+n_steps]
        # The targets, shifted by one
        y = np.zeros_like(x)
        try:
            y[:, :-1], y[:, -1] = x[:, 1:], arr[:, n+n_steps]
        except IndexError:
            y[:, :-1], y[:, -1] = x[:, 1:], arr[:, 0]
        yield x, y

# %% [markdown]
# ### Test Your Implementation
#
# Now I'll make some data sets and we can check out what's going on as we batch data. Here, as an example, I'm going to use a batch size of 10 and 50 sequence steps.

# %%
batches = get_batches(encoded, 10, 50)
x, y = next(batches)

# %%
print('x\n', x[:10, :10])
print('\ny\n', y[:10, :10])
# Out:
# x
#  [[41 28  2 69 80 42 82 53 59 32]
#  [53  2 71 53 70 20 80 53 13 20]
#  [75 36 70 43 32 32 16 81 42 72]
#  [70 53 15 17 82 36 70 13 53 28]
#  [53 36 80 53 36 72  5 53 72 36]
#  [53 61 80 53 62  2 72 32 20 70]
#  [28 42 70 53 52 20 71 42 53 24]
#  [29 53 76 17 80 53 70 20 62 53]
#  [80 53 36 72 70 48 80 43 53 78]
#  [53 72  2 36 15 53 80 20 53 28]]
#
# y
#  [[28  2 69 80 42 82 53 59 32 32]
#  [ 2 71 53 70 20 80 53 13 20 36]
#  [36 70 43 32 32 16 81 42 72  5]
#  [53 15 17 82 36 70 13 53 28 36]
#  [36 80 53 36 72  5 53 72 36 82]
#  [61 80 53 62  2 72 32 20 70 54]
#  [42 70 53 52 20 71 42 53 24 20]
#  [53 76 17 80 53 70 20 62 53 72]
#  [53 36 72 70 48 80 43 53 78 28]
#  [72  2 36 15 53 80 20 53 28 42]]

# %% [markdown]
# If you implemented `get_batches` correctly, the above output should look something like
# ```
# x
#  [[55 63 69 22  6 76 45  5 16 35]
#  [ 5 69  1  5 12 52  6  5 56 52]
#  [48 29 12 61 35 35  8 64 76 78]
#  [12  5 24 39 45 29 12 56  5 63]
#  [ 5 29  6  5 29 78 28  5 78 29]
#  [ 5 13  6  5 36 69 78 35 52 12]
#  [63 76 12  5 18 52  1 76  5 58]
#  [34  5 73 39  6  5 12 52 36  5]
#  [ 6  5 29 78 12 79  6 61  5 59]
#  [ 5 78 69 29 24  5  6 52  5 63]]
#
# y
#  [[63 69 22  6 76 45  5 16 35 35]
#  [69  1  5 12 52  6  5 56 52 29]
#  [29 12 61 35 35  8 64 76 78 28]
#  [ 5 24 39 45 29 12 56  5 63 29]
#  [29  6  5 29 78 28  5 78 29 45]
#  [13  6  5 36 69 78 35 52 12 43]
#  [76 12  5 18 52  1 76  5 58 52]
#  [ 5 73 39  6  5 12 52 36  5 78]
#  [ 5 29 78 12 79  6 61  5 59 63]
#  [78 69 29 24  5  6 52  5 63 76]]
#  ```
#  although the exact numbers will be different. Check to make sure the data is shifted over one step for `y`.

# %% [markdown]
# ---
# ## Defining the network with PyTorch
#
# Below is where you'll define the network. We'll break it up into parts so it's easier to reason about each bit. Then we can connect them up into the whole network.
#
# <img src="assets/charRNN.png" width=500px>
#
# Next, you'll use PyTorch to define the architecture of the network. We start by defining the layers and operations we want. Then, define a method for the forward pass. You've also been given a method for predicting characters.

# %% [markdown]
# ### Model Structure
#
# In `__init__` the suggested structure is as follows:
# * Create and store the necessary dictionaries (this has been done for you)
# * Define an LSTM layer that takes as params: an input size (the number of characters), a hidden layer size `n_hidden`, a number of layers `n_layers`, a dropout probability `drop_prob`, and a batch_first boolean (True, since we are batching)
# * Define a dropout layer with `dropout_prob`
# * Define a fully-connected layer with params: input size `n_hidden` and output size (the number of characters)
# * Finally, initialize the weights (again, this has been given)
#
# Note that some parameters have been named and given in the `__init__` function, and we use them and store them by doing something like `self.drop_prob = drop_prob`.

# %% [markdown]
# ---
# ### LSTM Inputs/Outputs
#
# You can create a basic LSTM cell as follows
#
# ```python
# self.lstm = nn.LSTM(input_size, n_hidden, n_layers,
#                             dropout=drop_prob, batch_first=True)
# ```
#
# where `input_size` is the number of characters this cell expects to see as sequential input, and `n_hidden` is the number of units in the hidden layers in the cell. And we can add dropout by adding a dropout parameter with a specified probability; this will automatically add dropout to the inputs or outputs. Finally, in the `forward` function, we can stack up the LSTM cells into layers using `.view`. With this, you pass in a list of cells and it will send the output of one cell into the next cell.
#
# We also need to create an initial cell state of all zeros. This is done like so
#
# ```python
# self.init_weights()
# ```

# %%
class CharRNN(nn.Module):
    
    def __init__(self, tokens, n_steps=100, n_hidden=256, n_layers=2,
                               drop_prob=0.5, lr=0.001):
        super().__init__()
        self.drop_prob = drop_prob
        self.n_layers = n_layers
        self.n_hidden = n_hidden
        self.lr = lr
        
        # creating character dictionaries
        self.chars = tokens
        self.int2char = dict(enumerate(self.chars))
        self.char2int = {ch: ii for ii, ch in self.int2char.items()}
        
        ## TODO: define the LSTM, self.lstm
        self.lstm=nn.LSTM(len(self.chars),n_hidden,n_layers,dropout=drop_prob,batch_first=True)
        
        ## TODO: define a dropout layer, self.dropout
        self.dropout=nn.Dropout(drop_prob)
        
        ## TODO: define the final, fully-connected output layer, self.fc
        self.fc=nn.Linear(n_hidden,len(self.chars))
        # initialize the weights
        self.init_weights()
      
    
    def forward(self, x, hc):
        ''' Forward pass through the network. 
            These inputs are x, and the hidden/cell state `hc`. '''
        
        ## TODO: Get x, and the new hidden state (h, c) from the lstm
        x, (h, c) = self.lstm(x, hc)
        
        ## TODO: pass x through a droupout layer
        x = self.dropout(x)
        
        # Stack up LSTM outputs using view
        x = x.view(x.size()[0]*x.size()[1], self.n_hidden)
        
        ## TODO: put x through the fully-connected layer
        x=self.fc(x)
        # return x and the hidden state (h, c)
        return x, (h, c)
    
    
    def predict(self, char, h=None, cuda=False, top_k=None):
        ''' Given a character, predict the next character.
        
            Returns the predicted character and the hidden state.
        '''
        if cuda:
            self.cuda()
        else:
            self.cpu()
        
        if h is None:
            h = self.init_hidden(1)
        
        x = np.array([[self.char2int[char]]])
        x = one_hot_encode(x, len(self.chars))
        inputs = torch.from_numpy(x)
        if cuda:
            inputs = inputs.cuda()
        
        h = tuple([each.data for each in h])
        out, h = self.forward(inputs, h)

        p = F.softmax(out, dim=1).data
        if cuda:
            p = p.cpu()
        
        if top_k is None:
            top_ch = np.arange(len(self.chars))
        else:
            p, top_ch = p.topk(top_k)
            top_ch = top_ch.numpy().squeeze()
        
        p = p.numpy().squeeze()
        char = np.random.choice(top_ch, p=p/p.sum())
            
        return self.int2char[char], h
    
    def init_weights(self):
        ''' Initialize weights for fully connected layer '''
        initrange = 0.1
        
        # Set bias tensor to all zeros
        self.fc.bias.data.fill_(0)
        # FC weights as random uniform
        self.fc.weight.data.uniform_(-1, 1)
        
    def init_hidden(self, n_seqs):
        ''' Initializes hidden state '''
        # Create two new tensors with sizes n_layers x n_seqs x n_hidden,
        # initialized to zero, for hidden state and cell state of LSTM
        weight = next(self.parameters()).data
        return (weight.new(self.n_layers, n_seqs, self.n_hidden).zero_(),
                weight.new(self.n_layers, n_seqs, self.n_hidden).zero_())

# %% [markdown]
# ### A note on the `predict`  function
#
# The output of our RNN is from a fully-connected layer and it outputs a **distribution of next-character scores**.
#
# To actually get the next character, we apply a softmax function, which gives us a *probability* distribution that we can then sample to predict the next character.

# %%
## ---- keep notebook from crashing during training --- ##
import os
import requests
import time

def train(net, data, epochs=10, n_seqs=10, n_steps=50, lr=0.001, clip=5, val_frac=0.1, cuda=False, print_every=10):
    ''' Training a network 
    
        Arguments
        ---------
        
        net: CharRNN network
        data: text data to train the network
        epochs: Number of epochs to train
        n_seqs: Number of mini-sequences per mini-batch, aka batch size
        n_steps: Number of character steps per mini-batch
        lr: learning rate
        clip: gradient clipping
        val_frac: Fraction of data to hold out for validation
        cuda: Train with CUDA on a GPU
        print_every: Number of steps for printing training and validation loss
    
    '''
    
    net.train()
    opt = torch.optim.Adam(net.parameters(), lr=lr)
    criterion = nn.CrossEntropyLoss()
    
    # create training and validation data
    val_idx = int(len(data)*(1-val_frac))
    data, val_data = data[:val_idx], data[val_idx:]
    
    if cuda:
        net.cuda()
    
    counter = 0
    n_chars = len(net.chars)
    
    old_time = time.time()

    for e in range(epochs):
        h = net.init_hidden(n_seqs)
        for x, y in get_batches(data, n_seqs, n_steps):
            
            if time.time() - old_time > 60:
                old_time = time.time()
                requests.request("POST", 
                                 "https://nebula.udacity.com/api/v1/remote/keep-alive", 
                                 headers={'Authorization': "STAR " + response.text})
            
            counter += 1
            
            # One-hot encode our data and make them Torch tensors
            x = one_hot_encode(x, n_chars)
            inputs, targets = torch.from_numpy(x), torch.from_numpy(y)
            
            if cuda:
                inputs, targets = inputs.cuda(), targets.cuda()

            # Creating new variables for the hidden state, otherwise
            # we'd backprop through the entire training history
            h = tuple([each.data for each in h])

            net.zero_grad()
            
            output, h = net.forward(inputs, h)
            loss = criterion(output, targets.view(n_seqs*n_steps))

            loss.backward()
            
            # `clip_grad_norm` helps prevent the exploding gradient problem in RNNs / LSTMs.
            nn.utils.clip_grad_norm_(net.parameters(), clip)

            opt.step()
            
            if counter % print_every == 0:
                
                # Get validation loss
                val_h = net.init_hidden(n_seqs)
                val_losses = []
                for x, y in get_batches(val_data, n_seqs, n_steps):
                    # One-hot encode our data and make them Torch tensors
                    x = one_hot_encode(x, n_chars)
                    x, y = torch.from_numpy(x), torch.from_numpy(y)
                    
                    # Creating new variables for the hidden state, otherwise
                    # we'd backprop through the entire training history
                    val_h = tuple([each.data for each in val_h])
                    
                    inputs, targets = x, y
                    if cuda:
                        inputs, targets = inputs.cuda(), targets.cuda()

                    output, val_h = net.forward(inputs, val_h)
                    val_loss = criterion(output, targets.view(n_seqs*n_steps))
                
                    val_losses.append(val_loss.item())
                
                print("Epoch: {}/{}...".format(e+1, epochs),
                      "Step: {}...".format(counter),
                      "Loss: {:.4f}...".format(loss.item()),
                      "Val Loss: {:.4f}".format(np.mean(val_losses)))

# %% [markdown]
# ## Time to train
#
# Now we can actually train the network. First we'll create the network itself, with some given hyperparameters. Then, define the mini-batches sizes (number of sequences and number of steps), and start the training. With the train function, we can set the number of epochs, the learning rate, and other parameters. Also, we can run the training on a GPU by setting `cuda=True`.

# %%
if 'net' in locals():
    del net

# %%
# define and print the net
net = CharRNN(chars, n_hidden=512, n_layers=2)
print(net)
# Out:
# CharRNN(
#   (lstm): LSTM(83, 512, num_layers=2, batch_first=True, dropout=0.5)
#   (dropout): Dropout(p=0.5)
#   (fc): Linear(in_features=512, out_features=83, bias=True)
# )

# %%
n_seqs, n_steps = 128, 100

# you may change cuda to True if you plan on using a GPU!
# also, if you do, please INCREASE the epochs to 25

# Open the training log file.
log_file = 'training_log.txt'
f = open(log_file, 'w')

response = requests.request("GET", 
                            "http://metadata.google.internal/computeMetadata/v1/instance/attributes/keep_alive_token", 
                            headers={"Metadata-Flavor":"Google"})

# TRAIN
train(net, encoded, epochs=30, n_seqs=n_seqs, n_steps=n_steps, lr=0.001, cuda=True, print_every=10)

# Close the training log file.
f.close()
# Out:
# Epoch: 1/30... Step: 10... Loss: 3.2391... Val Loss: 3.2319
# Epoch: 1/30... Step: 20... Loss: 3.0846... Val Loss: 3.0917
# Epoch: 1/30... Step: 30... Loss: 2.9447... Val Loss: 2.9269
# Epoch: 1/30... Step: 40... Loss: 2.7342... Val Loss: 2.7491
# Epoch: 1/30... Step: 50... Loss: 2.6560... Val Loss: 2.6336
# Epoch: 1/30... Step: 60... Loss: 2.5332... Val Loss: 2.5613
# Epoch: 1/30... Step: 70... Loss: 2.4830... Val Loss: 2.5013
# Epoch: 1/30... Step: 80... Loss: 2.4307... Val Loss: 2.4543
# Epoch: 1/30... Step: 90... Loss: 2.3984... Val Loss: 2.4173
# Epoch: 1/30... Step: 100... Loss: 2.3495... Val Loss: 2.3887
# Epoch: 1/30... Step: 110... Loss: 2.3122... Val Loss: 2.3590
# Epoch: 1/30... Step: 120... Loss: 2.2473... Val Loss: 2.3292
# Epoch: 1/30... Step: 130... Loss: 2.2794... Val Loss: 2.3053
# Epoch: 2/30... Step: 140... Loss: 2.2317... Val Loss: 2.2830
# Epoch: 2/30... Step: 150... Loss: 2.2109... Val Loss: 2.2824
# Epoch: 2/30... Step: 160... Loss: 2.1983... Val Loss: 2.2380
# Epoch: 2/30... Step: 170... Loss: 2.1584... Val Loss: 2.2143
# Epoch: 2/30... Step: 180... Loss: 2.1141... Val Loss: 2.1921
# Epoch: 2/30... Step: 190... Loss: 2.0653... Val Loss: 2.1745
# Epoch: 2/30... Step: 200... Loss: 2.0774... Val Loss: 2.1548
# Epoch: 2/30... Step: 210... Loss: 2.0612... Val Loss: 2.1335
# Epoch: 2/30... Step: 220... Loss: 2.0211... Val Loss: 2.1168
# Epoch: 2/30... Step: 230... Loss: 2.0518... Val Loss: 2.0953
# Epoch: 2/30... Step: 240... Loss: 2.0326... Val Loss: 2.0850
# Epoch: 2/30... Step: 250... Loss: 1.9777... Val Loss: 2.0644
# Epoch: 2/30... Step: 260... Loss: 1.9406... Val Loss: 2.0695
# Epoch: 2/30... Step: 270... Loss: 1.9626... Val Loss: 2.0357
# Epoch: 3/30... Step: 280... Loss: 1.9553... Val Loss: 2.0197
# Epoch: 3/30... Step: 290... Loss: 1.9569... Val Loss: 2.0070
# Epoch: 3/30... Step: 300... Loss: 1.9162... Val Loss: 1.9939
# Epoch: 3/30... Step: 310... Loss: 1.8949... Val Loss: 1.9823
# Epoch: 3/30... Step: 320... Loss: 1.8637... Val Loss: 1.9776
# Epoch: 3/30... Step: 330... Loss: 1.8603... Val Loss: 1.9625
# Epoch: 3/30... Step: 340... Loss: 1.8944... Val Loss: 1.9606
# Epoch: 3/30... Step: 350... Loss: 1.8377... Val Loss: 1.9340
# Epoch: 3/30... Step: 360... Loss: 1.8000... Val Loss: 1.9312
# Epoch: 3/30... Step: 370... Loss: 1.8349... Val Loss: 1.9197
# Epoch: 3/30... Step: 380... Loss: 1.8258... Val Loss: 1.9109
# Epoch: 3/30... Step: 390... Loss: 1.8013... Val Loss: 1.9057
# Epoch: 3/30... Step: 400... Loss: 1.7859... Val Loss: 1.8984
# Epoch: 3/30... Step: 410... Loss: 1.7951... Val Loss: 1.8916
# Epoch: 4/30... Step: 420... Loss: 1.7937... Val Loss: 1.8842
# Epoch: 4/30... Step: 430... Loss: 1.7899... Val Loss: 1.8707
# Epoch: 4/30... Step: 440... Loss: 1.7670... Val Loss: 1.8530
# Epoch: 4/30... Step: 450... Loss: 1.7242... Val Loss: 1.8436
# Epoch: 4/30... Step: 460... Loss: 1.7067... Val Loss: 1.8401
# Epoch: 4/30... Step: 470... Loss: 1.7528... Val Loss: 1.8281
# Epoch: 4/30... Step: 480... Loss: 1.7381... Val Loss: 1.8285
# Epoch: 4/30... Step: 490... Loss: 1.7322... Val Loss: 1.8133
# Epoch: 4/30... Step: 500... Loss: 1.7302... Val Loss: 1.8089
# Epoch: 4/30... Step: 510... Loss: 1.7013... Val Loss: 1.8003
# Epoch: 4/30... Step: 520... Loss: 1.7260... Val Loss: 1.7984
# Epoch: 4/30... Step: 530... Loss: 1.6972... Val Loss: 1.7880
# Epoch: 4/30... Step: 540... Loss: 1.6481... Val Loss: 1.7884
# Epoch: 4/30... Step: 550... Loss: 1.7118... Val Loss: 1.7722
# Epoch: 5/30... Step: 560... Loss: 1.6655... Val Loss: 1.7787
# Epoch: 5/30... Step: 570... Loss: 1.6614... Val Loss: 1.7638
# Epoch: 5/30... Step: 580... Loss: 1.6383... Val Loss: 1.7594
# Epoch: 5/30... Step: 590... Loss: 1.6321... Val Loss: 1.7591
# Epoch: 5/30... Step: 600... Loss: 1.6352... Val Loss: 1.7631
# Epoch: 5/30... Step: 610... Loss: 1.6177... Val Loss: 1.7449
# Epoch: 5/30... Step: 620... Loss: 1.6224... Val Loss: 1.7390
# Epoch: 5/30... Step: 630... Loss: 1.6511... Val Loss: 1.7300
# Epoch: 5/30... Step: 640... Loss: 1.5991... Val Loss: 1.7213
# Epoch: 5/30... Step: 650... Loss: 1.6080... Val Loss: 1.7177
# Epoch: 5/30... Step: 660... Loss: 1.5886... Val Loss: 1.7241
# Epoch: 5/30... Step: 670... Loss: 1.6140... Val Loss: 1.7071
# Epoch: 5/30... Step: 680... Loss: 1.5978... Val Loss: 1.7106
# Epoch: 5/30... Step: 690... Loss: 1.5850... Val Loss: 1.6934
# Epoch: 6/30... Step: 700... Loss: 1.5825... Val Loss: 1.7004
# Epoch: 6/30... Step: 710... Loss: 1.5686... Val Loss: 1.6821
# Epoch: 6/30... Step: 720... Loss: 1.5560... Val Loss: 1.6964
# Epoch: 6/30... Step: 730... Loss: 1.5759... Val Loss: 1.6762
# Epoch: 6/30... Step: 740... Loss: 1.5419... Val Loss: 1.6751
# Epoch: 6/30... Step: 750... Loss: 1.5297... Val Loss: 1.6688
# Epoch: 6/30... Step: 760... Loss: 1.5760... Val Loss: 1.6646
# Epoch: 6/30... Step: 770... Loss: 1.5491... Val Loss: 1.6565
# Epoch: 6/30... Step: 780... Loss: 1.5434... Val Loss: 1.6553
# Epoch: 6/30... Step: 790... Loss: 1.5136... Val Loss: 1.6492
# Epoch: 6/30... Step: 800... Loss: 1.5334... Val Loss: 1.6433
# Epoch: 6/30... Step: 810... Loss: 1.5167... Val Loss: 1.6451
# Epoch: 6/30... Step: 820... Loss: 1.4738... Val Loss: 1.6394
# Epoch: 6/30... Step: 830... Loss: 1.5328... Val Loss: 1.6399
# Epoch: 7/30... Step: 840... Loss: 1.4804... Val Loss: 1.6315
# Epoch: 7/30... Step: 850... Loss: 1.4964... Val Loss: 1.6271
# Epoch: 7/30... Step: 860... Loss: 1.4832... Val Loss: 1.6255
# Epoch: 7/30... Step: 870... Loss: 1.4963... Val Loss: 1.6197
# Epoch: 7/30... Step: 880... Loss: 1.5076... Val Loss: 1.6180
# Epoch: 7/30... Step: 890... Loss: 1.5080... Val Loss: 1.6095
# Epoch: 7/30... Step: 900... Loss: 1.4948... Val Loss: 1.6141
# Epoch: 7/30... Step: 910... Loss: 1.4450... Val Loss: 1.6085
# Epoch: 7/30... Step: 920... Loss: 1.4860... Val Loss: 1.6060
# Epoch: 7/30... Step: 930... Loss: 1.4625... Val Loss: 1.5976
# Epoch: 7/30... Step: 940... Loss: 1.4614... Val Loss: 1.6043
# Epoch: 7/30... Step: 950... Loss: 1.4700... Val Loss: 1.5970
# Epoch: 7/30... Step: 960... Loss: 1.4815... Val Loss: 1.5891
# Epoch: 7/30... Step: 970... Loss: 1.4829... Val Loss: 1.5940
# Epoch: 8/30... Step: 980... Loss: 1.4485... Val Loss: 1.5877
# Epoch: 8/30... Step: 990... Loss: 1.4503... Val Loss: 1.5839
# Epoch: 8/30... Step: 1000... Loss: 1.4492... Val Loss: 1.5928
# Epoch: 8/30... Step: 1010... Loss: 1.4835... Val Loss: 1.5776
# Epoch: 8/30... Step: 1020... Loss: 1.4637... Val Loss: 1.5764
# Epoch: 8/30... Step: 1030... Loss: 1.4348... Val Loss: 1.5759
# Epoch: 8/30... Step: 1040... Loss: 1.4561... Val Loss: 1.5753
# Epoch: 8/30... Step: 1050... Loss: 1.4239... Val Loss: 1.5724
# Epoch: 8/30... Step: 1060... Loss: 1.4316... Val Loss: 1.5682
# Epoch: 8/30... Step: 1070... Loss: 1.4354... Val Loss: 1.5631
# Epoch: 8/30... Step: 1080... Loss: 1.4359... Val Loss: 1.5622
# Epoch: 8/30... Step: 1090... Loss: 1.4267... Val Loss: 1.5633
# Epoch: 8/30... Step: 1100... Loss: 1.4181... Val Loss: 1.5596
# Epoch: 8/30... Step: 1110... Loss: 1.4149... Val Loss: 1.5650
# Epoch: 9/30... Step: 1120... Loss: 1.4246... Val Loss: 1.5621
# Epoch: 9/30... Step: 1130... Loss: 1.4272... Val Loss: 1.5471
# Epoch: 9/30... Step: 1140... Loss: 1.4281... Val Loss: 1.5485
# Epoch: 9/30... Step: 1150... Loss: 1.4480... Val Loss: 1.5465
# Epoch: 9/30... Step: 1160... Loss: 1.4030... Val Loss: 1.5461
# Epoch: 9/30... Step: 1170... Loss: 1.4077... Val Loss: 1.5483
# Epoch: 9/30... Step: 1180... Loss: 1.4142... Val Loss: 1.5498
# Epoch: 9/30... Step: 1190... Loss: 1.4352... Val Loss: 1.5457
# Epoch: 9/30... Step: 1200... Loss: 1.3859... Val Loss: 1.5366
# Epoch: 9/30... Step: 1210... Loss: 1.3906... Val Loss: 1.5372
# Epoch: 9/30... Step: 1220... Loss: 1.3962... Val Loss: 1.5329
# Epoch: 9/30... Step: 1230... Loss: 1.3736... Val Loss: 1.5267
# Epoch: 9/30... Step: 1240... Loss: 1.3812... Val Loss: 1.5253
# Epoch: 9/30... Step: 1250... Loss: 1.3927... Val Loss: 1.5265
# Epoch: 10/30... Step: 1260... Loss: 1.3903... Val Loss: 1.5332
# Epoch: 10/30... Step: 1270... Loss: 1.4015... Val Loss: 1.5229
# Epoch: 10/30... Step: 1280... Loss: 1.4089... Val Loss: 1.5218
# Epoch: 10/30... Step: 1290... Loss: 1.3823... Val Loss: 1.5263
# Epoch: 10/30... Step: 1300... Loss: 1.3825... Val Loss: 1.5237
# Epoch: 10/30... Step: 1310... Loss: 1.3900... Val Loss: 1.5145
# Epoch: 10/30... Step: 1320... Loss: 1.3606... Val Loss: 1.5164
# Epoch: 10/30... Step: 1330... Loss: 1.3638... Val Loss: 1.5152
# Epoch: 10/30... Step: 1340... Loss: 1.3618... Val Loss: 1.5139
# Epoch: 10/30... Step: 1350... Loss: 1.3518... Val Loss: 1.5263
# Epoch: 10/30... Step: 1360... Loss: 1.3610... Val Loss: 1.5126
# Epoch: 10/30... Step: 1370... Loss: 1.3384... Val Loss: 1.5093
# Epoch: 10/30... Step: 1380... Loss: 1.3788... Val Loss: 1.5032
# Epoch: 10/30... Step: 1390... Loss: 1.3951... Val Loss: 1.5111
# Epoch: 11/30... Step: 1400... Loss: 1.3897... Val Loss: 1.5085
# Epoch: 11/30... Step: 1410... Loss: 1.4013... Val Loss: 1.5008
# Epoch: 11/30... Step: 1420... Loss: 1.4004... Val Loss: 1.4996
# Epoch: 11/30... Step: 1430... Loss: 1.3565... Val Loss: 1.5015
# Epoch: 11/30... Step: 1440... Loss: 1.3786... Val Loss: 1.5015
# Epoch: 11/30... Step: 1450... Loss: 1.3247... Val Loss: 1.5002
# Epoch: 11/30... Step: 1460... Loss: 1.3346... Val Loss: 1.4982
# Epoch: 11/30... Step: 1470... Loss: 1.3301... Val Loss: 1.4921
# Epoch: 11/30... Step: 1480... Loss: 1.3449... Val Loss: 1.4914
# Epoch: 11/30... Step: 1490... Loss: 1.3366... Val Loss: 1.4917
# Epoch: 11/30... Step: 1500... Loss: 1.3253... Val Loss: 1.4860
# Epoch: 11/30... Step: 1510... Loss: 1.3045... Val Loss: 1.4841
# Epoch: 11/30... Step: 1520... Loss: 1.3426... Val Loss: 1.4874
# Epoch: 12/30... Step: 1530... Loss: 1.3905... Val Loss: 1.4836
# Epoch: 12/30... Step: 1540... Loss: 1.3428... Val Loss: 1.4844
# Epoch: 12/30... Step: 1550... Loss: 1.3605... Val Loss: 1.4802
# Epoch: 12/30... Step: 1560... Loss: 1.3639... Val Loss: 1.4780
# Epoch: 12/30... Step: 1570... Loss: 1.3131... Val Loss: 1.4821
# Epoch: 12/30... Step: 1580... Loss: 1.2976... Val Loss: 1.4825
# Epoch: 12/30... Step: 1590... Loss: 1.2879... Val Loss: 1.4805
# Epoch: 12/30... Step: 1600... Loss: 1.3124... Val Loss: 1.4750
# Epoch: 12/30... Step: 1610... Loss: 1.3073... Val Loss: 1.4861
# Epoch: 12/30... Step: 1620... Loss: 1.3113... Val Loss: 1.4795
# Epoch: 12/30... Step: 1630... Loss: 1.3356... Val Loss: 1.4809
# Epoch: 12/30... Step: 1640... Loss: 1.2986... Val Loss: 1.4772
# Epoch: 12/30... Step: 1650... Loss: 1.2872... Val Loss: 1.4720
# Epoch: 12/30... Step: 1660... Loss: 1.3342... Val Loss: 1.4729
# Epoch: 13/30... Step: 1670... Loss: 1.3099... Val Loss: 1.4753
# Epoch: 13/30... Step: 1680... Loss: 1.3176... Val Loss: 1.4740
# Epoch: 13/30... Step: 1690... Loss: 1.2897... Val Loss: 1.4685
# Epoch: 13/30... Step: 1700... Loss: 1.2973... Val Loss: 1.4622
# Epoch: 13/30... Step: 1710... Loss: 1.2756... Val Loss: 1.4662
# Epoch: 13/30... Step: 1720... Loss: 1.2819... Val Loss: 1.4703
# Epoch: 13/30... Step: 1730... Loss: 1.3232... Val Loss: 1.4699
# Epoch: 13/30... Step: 1740... Loss: 1.2945... Val Loss: 1.4663
# Epoch: 13/30... Step: 1750... Loss: 1.2606... Val Loss: 1.4597
# Epoch: 13/30... Step: 1760... Loss: 1.2871... Val Loss: 1.4675
# Epoch: 13/30... Step: 1770... Loss: 1.3137... Val Loss: 1.4598
# Epoch: 13/30... Step: 1780... Loss: 1.2807... Val Loss: 1.4584
# Epoch: 13/30... Step: 1790... Loss: 1.2777... Val Loss: 1.4673
# Epoch: 13/30... Step: 1800... Loss: 1.2978... Val Loss: 1.4648
# Epoch: 14/30... Step: 1810... Loss: 1.3036... Val Loss: 1.4606
# Epoch: 14/30... Step: 1820... Loss: 1.2864... Val Loss: 1.4619
# Epoch: 14/30... Step: 1830... Loss: 1.3050... Val Loss: 1.4558
# Epoch: 14/30... Step: 1840... Loss: 1.2569... Val Loss: 1.4546
# Epoch: 14/30... Step: 1850... Loss: 1.2335... Val Loss: 1.4581
# Epoch: 14/30... Step: 1860... Loss: 1.2867... Val Loss: 1.4524
# Epoch: 14/30... Step: 1870... Loss: 1.2988... Val Loss: 1.4578
# Epoch: 14/30... Step: 1880... Loss: 1.2958... Val Loss: 1.4546
# Epoch: 14/30... Step: 1890... Loss: 1.3071... Val Loss: 1.4503
# Epoch: 14/30... Step: 1900... Loss: 1.2855... Val Loss: 1.4423
# Epoch: 14/30... Step: 1910... Loss: 1.2776... Val Loss: 1.4423
# Epoch: 14/30... Step: 1920... Loss: 1.2805... Val Loss: 1.4454
# Epoch: 14/30... Step: 1930... Loss: 1.2447... Val Loss: 1.4529
# Epoch: 14/30... Step: 1940... Loss: 1.2980... Val Loss: 1.4447
# Epoch: 15/30... Step: 1950... Loss: 1.2696... Val Loss: 1.4456
# Epoch: 15/30... Step: 1960... Loss: 1.2765... Val Loss: 1.4521
# Epoch: 15/30... Step: 1970... Loss: 1.2678... Val Loss: 1.4409
# Epoch: 15/30... Step: 1980... Loss: 1.2521... Val Loss: 1.4425
# Epoch: 15/30... Step: 1990... Loss: 1.2554... Val Loss: 1.4502
# Epoch: 15/30... Step: 2000... Loss: 1.2453... Val Loss: 1.4425
# Epoch: 15/30... Step: 2010... Loss: 1.2632... Val Loss: 1.4400
# Epoch: 15/30... Step: 2020... Loss: 1.2764... Val Loss: 1.4466
# Epoch: 15/30... Step: 2030... Loss: 1.2482... Val Loss: 1.4393
# Epoch: 15/30... Step: 2040... Loss: 1.2720... Val Loss: 1.4371
# Epoch: 15/30... Step: 2050... Loss: 1.2596... Val Loss: 1.4379
# Epoch: 15/30... Step: 2060... Loss: 1.2577... Val Loss: 1.4427
# Epoch: 15/30... Step: 2070... Loss: 1.2732... Val Loss: 1.4389
# Epoch: 15/30... Step: 2080... Loss: 1.2603... Val Loss: 1.4381
# Epoch: 16/30... Step: 2090... Loss: 1.2641... Val Loss: 1.4341
# Epoch: 16/30... Step: 2100... Loss: 1.2475... Val Loss: 1.4436
# Epoch: 16/30... Step: 2110... Loss: 1.2516... Val Loss: 1.4343
# Epoch: 16/30... Step: 2120... Loss: 1.2589... Val Loss: 1.4418
# Epoch: 16/30... Step: 2130... Loss: 1.2473... Val Loss: 1.4422
# Epoch: 16/30... Step: 2140... Loss: 1.2550... Val Loss: 1.4386
# Epoch: 16/30... Step: 2150... Loss: 1.2657... Val Loss: 1.4381
# Epoch: 16/30... Step: 2160... Loss: 1.2465... Val Loss: 1.4366
# Epoch: 16/30... Step: 2170... Loss: 1.2564... Val Loss: 1.4404
# Epoch: 16/30... Step: 2180... Loss: 1.2457... Val Loss: 1.4391
# Epoch: 16/30... Step: 2190... Loss: 1.2567... Val Loss: 1.4320
# Epoch: 16/30... Step: 2200... Loss: 1.2526... Val Loss: 1.4326
# Epoch: 16/30... Step: 2210... Loss: 1.2043... Val Loss: 1.4283
# Epoch: 16/30... Step: 2220... Loss: 1.2597... Val Loss: 1.4283
# Epoch: 17/30... Step: 2230... Loss: 1.2254... Val Loss: 1.4271
# Epoch: 17/30... Step: 2240... Loss: 1.2237... Val Loss: 1.4257
# Epoch: 17/30... Step: 2250... Loss: 1.2218... Val Loss: 1.4228
# Epoch: 17/30... Step: 2260... Loss: 1.2368... Val Loss: 1.4269
# Epoch: 17/30... Step: 2270... Loss: 1.2377... Val Loss: 1.4352
# Epoch: 17/30... Step: 2280... Loss: 1.2574... Val Loss: 1.4276
# Epoch: 17/30... Step: 2290... Loss: 1.2466... Val Loss: 1.4256
# Epoch: 17/30... Step: 2300... Loss: 1.2047... Val Loss: 1.4319
# Epoch: 17/30... Step: 2310... Loss: 1.2427... Val Loss: 1.4271
# Epoch: 17/30... Step: 2320... Loss: 1.2234... Val Loss: 1.4140
# Epoch: 17/30... Step: 2330... Loss: 1.2269... Val Loss: 1.4191
# Epoch: 17/30... Step: 2340... Loss: 1.2308... Val Loss: 1.4263
# Epoch: 17/30... Step: 2350... Loss: 1.2379... Val Loss: 1.4222
# Epoch: 17/30... Step: 2360... Loss: 1.2508... Val Loss: 1.4178
# Epoch: 18/30... Step: 2370... Loss: 1.2166... Val Loss: 1.4215
# Epoch: 18/30... Step: 2380... Loss: 1.2309... Val Loss: 1.4246
# Epoch: 18/30... Step: 2390... Loss: 1.2109... Val Loss: 1.4192
# Epoch: 18/30... Step: 2400... Loss: 1.2407... Val Loss: 1.4148
# Epoch: 18/30... Step: 2410... Loss: 1.2477... Val Loss: 1.4183
# Epoch: 18/30... Step: 2420... Loss: 1.2298... Val Loss: 1.4136
# Epoch: 18/30... Step: 2430... Loss: 1.2316... Val Loss: 1.4121
# Epoch: 18/30... Step: 2440... Loss: 1.2132... Val Loss: 1.4227
# Epoch: 18/30... Step: 2450... Loss: 1.2031... Val Loss: 1.4235
# Epoch: 18/30... Step: 2460... Loss: 1.2293... Val Loss: 1.4196
# Epoch: 18/30... Step: 2470... Loss: 1.2243... Val Loss: 1.4156
# Epoch: 18/30... Step: 2480... Loss: 1.2115... Val Loss: 1.4192
# Epoch: 18/30... Step: 2490... Loss: 1.2047... Val Loss: 1.4136
# Epoch: 18/30... Step: 2500... Loss: 1.2050... Val Loss: 1.4143
# Epoch: 19/30... Step: 2510... Loss: 1.2095... Val Loss: 1.4099
# Epoch: 19/30... Step: 2520... Loss: 1.2218... Val Loss: 1.4154
# Epoch: 19/30... Step: 2530... Loss: 1.2300... Val Loss: 1.4144
# Epoch: 19/30... Step: 2540... Loss: 1.2415... Val Loss: 1.4148
# Epoch: 19/30... Step: 2550... Loss: 1.2168... Val Loss: 1.4195
# Epoch: 19/30... Step: 2560... Loss: 1.2222... Val Loss: 1.4117
# Epoch: 19/30... Step: 2570... Loss: 1.2082... Val Loss: 1.4127
# Epoch: 19/30... Step: 2580... Loss: 1.2298... Val Loss: 1.4097
# Epoch: 19/30... Step: 2590... Loss: 1.1996... Val Loss: 1.4209
# Epoch: 19/30... Step: 2600... Loss: 1.1891... Val Loss: 1.4082
# Epoch: 19/30... Step: 2610... Loss: 1.2038... Val Loss: 1.4037
# Epoch: 19/30... Step: 2620... Loss: 1.1875... Val Loss: 1.4070
# Epoch: 19/30... Step: 2630... Loss: 1.1894... Val Loss: 1.4036
# Epoch: 19/30... Step: 2640... Loss: 1.2028... Val Loss: 1.4020
# Epoch: 20/30... Step: 2650... Loss: 1.2022... Val Loss: 1.4088
# Epoch: 20/30... Step: 2660... Loss: 1.2132... Val Loss: 1.4044
# Epoch: 20/30... Step: 2670... Loss: 1.2319... Val Loss: 1.4078
# Epoch: 20/30... Step: 2680... Loss: 1.2034... Val Loss: 1.4076
# Epoch: 20/30... Step: 2690... Loss: 1.2020... Val Loss: 1.4094
# Epoch: 20/30... Step: 2700... Loss: 1.2061... Val Loss: 1.4015
# Epoch: 20/30... Step: 2710... Loss: 1.1888... Val Loss: 1.4038
# Epoch: 20/30... Step: 2720... Loss: 1.1815... Val Loss: 1.4016
# Epoch: 20/30... Step: 2730... Loss: 1.1746... Val Loss: 1.4075
# Epoch: 20/30... Step: 2740... Loss: 1.1821... Val Loss: 1.4084
# Epoch: 20/30... Step: 2750... Loss: 1.1832... Val Loss: 1.4011
# Epoch: 20/30... Step: 2760... Loss: 1.1736... Val Loss: 1.4088
# Epoch: 20/30... Step: 2770... Loss: 1.2152... Val Loss: 1.4029
# Epoch: 20/30... Step: 2780... Loss: 1.2462... Val Loss: 1.3985
# Epoch: 21/30... Step: 2790... Loss: 1.2156... Val Loss: 1.3968
# Epoch: 21/30... Step: 2800... Loss: 1.2342... Val Loss: 1.3910
# Epoch: 21/30... Step: 2810... Loss: 1.2351... Val Loss: 1.4035
# Epoch: 21/30... Step: 2820... Loss: 1.1968... Val Loss: 1.3977
# Epoch: 21/30... Step: 2830... Loss: 1.2020... Val Loss: 1.3956
# Epoch: 21/30... Step: 2840... Loss: 1.1594... Val Loss: 1.3918
# Epoch: 21/30... Step: 2850... Loss: 1.1805... Val Loss: 1.3952
# Epoch: 21/30... Step: 2860... Loss: 1.1701... Val Loss: 1.4034
# Epoch: 21/30... Step: 2870... Loss: 1.1925... Val Loss: 1.4054
# Epoch: 21/30... Step: 2880... Loss: 1.1751... Val Loss: 1.3972
# Epoch: 21/30... Step: 2890... Loss: 1.1708... Val Loss: 1.3948
# Epoch: 21/30... Step: 2900... Loss: 1.1548... Val Loss: 1.4004
# Epoch: 21/30... Step: 2910... Loss: 1.1805... Val Loss: 1.3956
# Epoch: 22/30... Step: 2920... Loss: 1.2649... Val Loss: 1.3982
# Epoch: 22/30... Step: 2930... Loss: 1.1847... Val Loss: 1.3937
# Epoch: 22/30... Step: 2940... Loss: 1.1991... Val Loss: 1.3935
# Epoch: 22/30... Step: 2950... Loss: 1.2166... Val Loss: 1.3958
# Epoch: 22/30... Step: 2960... Loss: 1.1682... Val Loss: 1.3925
# Epoch: 22/30... Step: 2970... Loss: 1.1539... Val Loss: 1.3898
# Epoch: 22/30... Step: 2980... Loss: 1.1517... Val Loss: 1.3902
# Epoch: 22/30... Step: 2990... Loss: 1.1672... Val Loss: 1.3862
# Epoch: 22/30... Step: 3000... Loss: 1.1553... Val Loss: 1.3929
# Epoch: 22/30... Step: 3010... Loss: 1.1596... Val Loss: 1.3963
# Epoch: 22/30... Step: 3020... Loss: 1.1753... Val Loss: 1.3934
# Epoch: 22/30... Step: 3030... Loss: 1.1503... Val Loss: 1.3956
# Epoch: 22/30... Step: 3040... Loss: 1.1362... Val Loss: 1.3936
# Epoch: 22/30... Step: 3050... Loss: 1.1939... Val Loss: 1.3914
# Epoch: 23/30... Step: 3060... Loss: 1.1635... Val Loss: 1.3905
# Epoch: 23/30... Step: 3070... Loss: 1.1726... Val Loss: 1.3859
# Epoch: 23/30... Step: 3080... Loss: 1.1483... Val Loss: 1.3878
# Epoch: 23/30... Step: 3090... Loss: 1.1556... Val Loss: 1.3882
# Epoch: 23/30... Step: 3100... Loss: 1.1382... Val Loss: 1.3908
# Epoch: 23/30... Step: 3110... Loss: 1.1383... Val Loss: 1.3923
# Epoch: 23/30... Step: 3120... Loss: 1.1806... Val Loss: 1.3889
# Epoch: 23/30... Step: 3130... Loss: 1.1476... Val Loss: 1.3888
# Epoch: 23/30... Step: 3140... Loss: 1.1236... Val Loss: 1.3921
# Epoch: 23/30... Step: 3150... Loss: 1.1509... Val Loss: 1.3926
# Epoch: 23/30... Step: 3160... Loss: 1.1751... Val Loss: 1.3920
# Epoch: 23/30... Step: 3170... Loss: 1.1475... Val Loss: 1.3939
# Epoch: 23/30... Step: 3180... Loss: 1.1333... Val Loss: 1.3922
# Epoch: 23/30... Step: 3190... Loss: 1.1579... Val Loss: 1.3855
# Epoch: 24/30... Step: 3200... Loss: 1.1773... Val Loss: 1.3839
# Epoch: 24/30... Step: 3210... Loss: 1.1407... Val Loss: 1.3897
# Epoch: 24/30... Step: 3220... Loss: 1.1655... Val Loss: 1.3857
# Epoch: 24/30... Step: 3230... Loss: 1.1278... Val Loss: 1.3811
# Epoch: 24/30... Step: 3240... Loss: 1.1096... Val Loss: 1.3841
# Epoch: 24/30... Step: 3250... Loss: 1.1531... Val Loss: 1.3919
# Epoch: 24/30... Step: 3260... Loss: 1.1723... Val Loss: 1.3853
# Epoch: 24/30... Step: 3270... Loss: 1.1726... Val Loss: 1.3843
# Epoch: 24/30... Step: 3280... Loss: 1.1709... Val Loss: 1.3925
# Epoch: 24/30... Step: 3290... Loss: 1.1474... Val Loss: 1.3942
# Epoch: 24/30... Step: 3300... Loss: 1.1462... Val Loss: 1.3942
# Epoch: 24/30... Step: 3310... Loss: 1.1502... Val Loss: 1.3950
# Epoch: 24/30... Step: 3320... Loss: 1.1127... Val Loss: 1.3915
# Epoch: 24/30... Step: 3330... Loss: 1.1702... Val Loss: 1.3833
# Epoch: 25/30... Step: 3340... Loss: 1.1518... Val Loss: 1.3853
# Epoch: 25/30... Step: 3350... Loss: 1.1689... Val Loss: 1.3870
# Epoch: 25/30... Step: 3360... Loss: 1.1459... Val Loss: 1.3832
# Epoch: 25/30... Step: 3370... Loss: 1.1467... Val Loss: 1.3914
# Epoch: 25/30... Step: 3380... Loss: 1.1392... Val Loss: 1.3834
# Epoch: 25/30... Step: 3390... Loss: 1.1233... Val Loss: 1.3812
# Epoch: 25/30... Step: 3400... Loss: 1.1513... Val Loss: 1.3847
# Epoch: 25/30... Step: 3410... Loss: 1.1514... Val Loss: 1.3884
# Epoch: 25/30... Step: 3420... Loss: 1.1387... Val Loss: 1.3792
# Epoch: 25/30... Step: 3430... Loss: 1.1383... Val Loss: 1.3797
# Epoch: 25/30... Step: 3440... Loss: 1.1269... Val Loss: 1.3817
# Epoch: 25/30... Step: 3450... Loss: 1.1428... Val Loss: 1.3917
# Epoch: 25/30... Step: 3460... Loss: 1.1572... Val Loss: 1.3875
# Epoch: 25/30... Step: 3470... Loss: 1.1456... Val Loss: 1.3747
# Epoch: 26/30... Step: 3480... Loss: 1.1647... Val Loss: 1.3771
# Epoch: 26/30... Step: 3490... Loss: 1.1479... Val Loss: 1.3815
# Epoch: 26/30... Step: 3500... Loss: 1.1290... Val Loss: 1.3789
# Epoch: 26/30... Step: 3510... Loss: 1.1531... Val Loss: 1.3873
# Epoch: 26/30... Step: 3520... Loss: 1.1277... Val Loss: 1.3779
# Epoch: 26/30... Step: 3530... Loss: 1.1340... Val Loss: 1.3937
# Epoch: 26/30... Step: 3540... Loss: 1.1592... Val Loss: 1.3881
# Epoch: 26/30... Step: 3550... Loss: 1.1264... Val Loss: 1.3881
# Epoch: 26/30... Step: 3560... Loss: 1.1227... Val Loss: 1.3919
# Epoch: 26/30... Step: 3570... Loss: 1.1302... Val Loss: 1.3907
# Epoch: 26/30... Step: 3580... Loss: 1.1494... Val Loss: 1.3933
# Epoch: 26/30... Step: 3590... Loss: 1.1319... Val Loss: 1.3949
# Epoch: 26/30... Step: 3600... Loss: 1.0970... Val Loss: 1.3861
# Epoch: 26/30... Step: 3610... Loss: 1.1456... Val Loss: 1.3789
# Epoch: 27/30... Step: 3620... Loss: 1.1262... Val Loss: 1.3796
# Epoch: 27/30... Step: 3630... Loss: 1.1239... Val Loss: 1.3816
# Epoch: 27/30... Step: 3640... Loss: 1.1032... Val Loss: 1.3882
# Epoch: 27/30... Step: 3650... Loss: 1.1238... Val Loss: 1.3832
# Epoch: 27/30... Step: 3660... Loss: 1.1295... Val Loss: 1.3850
# Epoch: 27/30... Step: 3670... Loss: 1.1373... Val Loss: 1.3871
# Epoch: 27/30... Step: 3680... Loss: 1.1438... Val Loss: 1.3850
# Epoch: 27/30... Step: 3690... Loss: 1.1039... Val Loss: 1.3854
# Epoch: 27/30... Step: 3700... Loss: 1.1261... Val Loss: 1.3844
# Epoch: 27/30... Step: 3710... Loss: 1.1262... Val Loss: 1.3807
# Epoch: 27/30... Step: 3720... Loss: 1.1144... Val Loss: 1.3816
# Epoch: 27/30... Step: 3730... Loss: 1.1298... Val Loss: 1.3848
# Epoch: 27/30... Step: 3740... Loss: 1.1331... Val Loss: 1.3783
# Epoch: 27/30... Step: 3750... Loss: 1.1398... Val Loss: 1.3810
# Epoch: 28/30... Step: 3760... Loss: 1.1178... Val Loss: 1.3799
# Epoch: 28/30... Step: 3770... Loss: 1.1262... Val Loss: 1.3866
# Epoch: 28/30... Step: 3780... Loss: 1.1223... Val Loss: 1.3860
# Epoch: 28/30... Step: 3790... Loss: 1.1399... Val Loss: 1.3828
# Epoch: 28/30... Step: 3800... Loss: 1.1325... Val Loss: 1.3822
# Epoch: 28/30... Step: 3810... Loss: 1.1196... Val Loss: 1.3850
# Epoch: 28/30... Step: 3820... Loss: 1.1271... Val Loss: 1.3836
# Epoch: 28/30... Step: 3830... Loss: 1.1108... Val Loss: 1.3788
# Epoch: 28/30... Step: 3840... Loss: 1.0995... Val Loss: 1.3852
# Epoch: 28/30... Step: 3850... Loss: 1.1275... Val Loss: 1.3806
# Epoch: 28/30... Step: 3860... Loss: 1.1154... Val Loss: 1.3770
# Epoch: 28/30... Step: 3870... Loss: 1.1086... Val Loss: 1.3869
# Epoch: 28/30... Step: 3880... Loss: 1.1022... Val Loss: 1.3787
# Epoch: 28/30... Step: 3890... Loss: 1.1061... Val Loss: 1.3823
# Epoch: 29/30... Step: 3900... Loss: 1.1197... Val Loss: 1.3781
# Epoch: 29/30... Step: 3910... Loss: 1.1269... Val Loss: 1.3818
# Epoch: 29/30... Step: 3920... Loss: 1.1258... Val Loss: 1.3857
# Epoch: 29/30... Step: 3930... Loss: 1.1410... Val Loss: 1.3885
# Epoch: 29/30... Step: 3940... Loss: 1.1098... Val Loss: 1.3775
# Epoch: 29/30... Step: 3950... Loss: 1.1246... Val Loss: 1.3803
# Epoch: 29/30... Step: 3960... Loss: 1.1014... Val Loss: 1.3829
# Epoch: 29/30... Step: 3970... Loss: 1.1201... Val Loss: 1.3854
# Epoch: 29/30... Step: 3980... Loss: 1.1058... Val Loss: 1.3825
# Epoch: 29/30... Step: 3990... Loss: 1.1058... Val Loss: 1.3796
# Epoch: 29/30... Step: 4000... Loss: 1.1025... Val Loss: 1.3810
# Epoch: 29/30... Step: 4010... Loss: 1.0957... Val Loss: 1.3807
# Epoch: 29/30... Step: 4020... Loss: 1.1035... Val Loss: 1.3660
# Epoch: 29/30... Step: 4030... Loss: 1.1245... Val Loss: 1.3770
# Epoch: 30/30... Step: 4040... Loss: 1.1190... Val Loss: 1.3742
# Epoch: 30/30... Step: 4050... Loss: 1.1216... Val Loss: 1.3807
# Epoch: 30/30... Step: 4060... Loss: 1.1320... Val Loss: 1.3845
# Epoch: 30/30... Step: 4070... Loss: 1.1081... Val Loss: 1.3866
# Epoch: 30/30... Step: 4080... Loss: 1.1125... Val Loss: 1.3733
# Epoch: 30/30... Step: 4090... Loss: 1.1130... Val Loss: 1.3776
# Epoch: 30/30... Step: 4100... Loss: 1.0908... Val Loss: 1.3729
# Epoch: 30/30... Step: 4110... Loss: 1.0837... Val Loss: 1.3811
# Epoch: 30/30... Step: 4120... Loss: 1.0889... Val Loss: 1.3879
# Epoch: 30/30... Step: 4130... Loss: 1.0923... Val Loss: 1.3830
# Epoch: 30/30... Step: 4140... Loss: 1.1006... Val Loss: 1.3824
# Epoch: 30/30... Step: 4150... Loss: 1.0890... Val Loss: 1.3802
# Epoch: 30/30... Step: 4160... Loss: 1.1223... Val Loss: 1.3660
# Epoch: 30/30... Step: 4170... Loss: 1.1559... Val Loss: 1.3636

# %% [markdown]
# ## Getting the best model
#
# To set your hyperparameters to get the best performance, you'll want to watch the training and validation losses. If your training loss is much lower than the validation loss, you're overfitting. Increase regularization (more dropout) or use a smaller network. If the training and validation losses are close, you're underfitting so you can increase the size of the network.

# %% [markdown]
# ## Hyperparameters
#
# Here are the hyperparameters for the network.
#
# In defining the model:
# * `n_hidden` - The number of units in the hidden layers.
# * `n_layers` - Number of hidden LSTM layers to use.
#
# We assume that dropout probability and learning rate will be kept at the default, in this example.
#
# And in training:
# * `n_seqs` - Number of sequences running through the network in one pass.
# * `n_steps` - Number of characters in the sequence the network is trained on. Larger is better typically, the network will learn more long range dependencies. But it takes longer to train. 100 is typically a good number here.
# * `lr` - Learning rate for training
#
# Here's some good advice from Andrej Karpathy on training the network. I'm going to copy it in here for your benefit, but also link to [where it originally came from](https://github.com/karpathy/char-rnn#tips-and-tricks).
#
# > ## Tips and Tricks
#
# >### Monitoring Validation Loss vs. Training Loss
# >If you're somewhat new to Machine Learning or Neural Networks it can take a bit of expertise to get good models. The most important quantity to keep track of is the difference between your training loss (printed during training) and the validation loss (printed once in a while when the RNN is run on the validation data (by default every 1000 iterations)). In particular:
#
# > - If your training loss is much lower than validation loss then this means the network might be **overfitting**. Solutions to this are to decrease your network size, or to increase dropout. For example you could try dropout of 0.5 and so on.
# > - If your training/validation loss are about equal then your model is **underfitting**. Increase the size of your model (either number of layers or the raw number of neurons per layer)
#
# > ### Approximate number of parameters
#
# > The two most important parameters that control the model are `n_hidden` and `n_layers`. I would advise that you always use `n_layers` of either 2/3. The `n_hidden` can be adjusted based on how much data you have. The two important quantities to keep track of here are:
#
# > - The number of parameters in your model. This is printed when you start training.
# > - The size of your dataset. 1MB file is approximately 1 million characters.
#
# >These two should be about the same order of magnitude. It's a little tricky to tell. Here are some examples:
#
# > - I have a 100MB dataset and I'm using the default parameter settings (which currently print 150K parameters). My data size is significantly larger (100 mil >> 0.15 mil), so I expect to heavily underfit. I am thinking I can comfortably afford to make `n_hidden` larger.
# > - I have a 10MB dataset and running a 10 million parameter model. I'm slightly nervous and I'm carefully monitoring my validation loss. If it's larger than my training loss then I may want to try to increase dropout a bit and see if that helps the validation loss.
#
# > ### Best models strategy
#
# >The winning strategy to obtaining very good models (if you have the compute time) is to always err on making the network larger (as large as you're willing to wait for it to compute) and then try different dropout values (between 0,1). Whatever model has the best validation performance (the loss, written in the checkpoint filename, low is good) is the one you should use in the end.
#
# >It is very common in deep learning to run many different models with many different hyperparameter settings, and in the end take whatever checkpoint gave the best validation performance.
#
# >By the way, the size of your training and validation splits are also parameters. Make sure you have a decent amount of data in your validation set or otherwise the validation performance will be noisy and not very informative.

# %% [markdown]
# After training, we'll save the model so we can load it again later if we need too. Here I'm saving the parameters needed to create the same architecture, the hidden layer hyperparameters and the text characters.

# %%
# change the name, for saving multiple files
model_name = 'rnn_1_epoch.net'

checkpoint = {'n_hidden': net.n_hidden,
              'n_layers': net.n_layers,
              'state_dict': net.state_dict(),
              'tokens': net.chars}

with open(model_name, 'wb') as f:
    torch.save(checkpoint, f)

# %% [markdown]
# ## Sampling
#
# Now that the model is trained, we'll want to sample from it. To sample, we pass in a character and have the network predict the next character. Then we take that character, pass it back in, and get another predicted character. Just keep doing this and you'll generate a bunch of text!
#
# ### Top K sampling
#
# Our predictions come from a categorcial probability distribution over all the possible characters. We can make the sample text and make it more reasonable to handle (with less variables) by only considering some $K$ most probable characters. This will prevent the network from giving us completely absurd characters while allowing it to introduce some noise and randomness into the sampled text.
#
# Typically you'll want to prime the network so you can build up a hidden state. Otherwise the network will start out generating characters at random. In general the first bunch of characters will be a little rough since it hasn't built up a long history of characters to predict from.

# %%
def sample(net, size, prime='The', top_k=None, cuda=False):
        
    if cuda:
        net.cuda()
    else:
        net.cpu()

    net.eval()
    
    # First off, run through the prime characters
    chars = [ch for ch in prime]
    h = net.init_hidden(1)
    for ch in prime:
        char, h = net.predict(ch, h, cuda=cuda, top_k=top_k)

    chars.append(char)
    
    # Now pass in the previous character and get a new one
    for ii in range(size):
        char, h = net.predict(chars[-1], h, cuda=cuda, top_k=top_k)
        chars.append(char)

    return ''.join(chars)

# %%
print(sample(net, 2000, prime='Anna', top_k=5, cuda=False))
# Out:
# Anna's brother's shall
# offerened for times, too, which they came to her hostily.
#
# "I did not say, but in the passing is a sister, to mean you. What decord,
# isn't you to did his forever!" she said.
#
# She did not help speaking of her, she fancied that he could
# not be seen her, so as he was at the same, who could not be angry
# to him. He felt her more strange from his femenes, and and that
# something was hust from a conversation with her. She did not say
# such a marsh on the state of the peculiar standing all his way and
# change time for the contrary that were all the passions of the satiffic
# struggles of acquaintances, and the solition of the matter at the forest
# way of the season of his face was to be at the same time. And
# he was in the most solation of this work on her.
#
# "Ah, how is you attract ones?"
#
# "You stay him three directly with the forest that I were all that
# would be serenely for the princess. I'm very well; but I'm very grateful
# to me," she said with him to her studios on the relations of his
# chief sick-nearness--and had been taken, and that independent in his
# boots. The class she had thought that the sight of her eyes were
# the face of the carriage severe to him, and was not to blame at happiness,
# the person of all these words to begin the parts that taking up the
# position of himself in the moments and twenty-convercable to be
# the morrifal subject. The sone of the distunces of the clever sense of
# her life. This came of thinking of them. To the second throw household he
# went to society. All these weeks there and moneys of the
# still was she seeing her. And thinking of it all this and such desperate
# personal stast at the same tatte of a life was the pathers of the same,
# though he were a long while begged him into the sight of his wife's
# child, that if she was aware it was towards his child on their
# peasants at the secret, that he had been some father, both, too
# all that winter all her existences as to the calm thousand, had an
# effort of the committee to see him. He saw

# %% [markdown]
# ## Loading a checkpoint

# %%
# Here we have loaded in a model that trained over 1 epoch `rnn_1_epoch.net`
with open('rnn_1_epoch.net', 'rb') as f:
    checkpoint = torch.load(f)
    
loaded = CharRNN(checkpoint['tokens'], n_hidden=checkpoint['n_hidden'], n_layers=checkpoint['n_layers'])
loaded.load_state_dict(checkpoint['state_dict'])

# %%
# Change cuda to True if you are using GPU!
print(sample(loaded, 2000, cuda=False, top_k=5, prime="And Levin said"))
# Out:
# And Levin said: "The boys and
# some doctor say is that all in that sinting of this soup of a strange
# acres, and that is no one, all his wife..."
#
# "It's all sick, things. I've not troubled you all so..."
#
# Alexey Alexandrovitch, still so as his sister of his fingers.
#
# "I haven't to be doubted?... I say nothing about it." And her first was on
# the station and the struggle of his will, talking of her son and the
# still--the sight of the count of with some seeing the same way, he
# walked about the steps and stocting, seeing the child, and
# towards a commission the mother they came off, and shame, he feels, to come and
# day, and then he seen the money of talk of the prince, though he could
# never be delighted. And the doctor should have all ten orders to the
# provide, had been a perpapt time to hear in through the parting the
# sendence.
#
# Stepan Arkadyevitch was not the fifther and all the stands of the communication
# of the faces and the miles of the mearor to stay to him of all his sense of
# the power and truthful service of terrible and timid and coats, and a glass, and
# at one chief call and deciding in his study, the pleasures there, who was to
# begin in the morning at the manter. She did not know what, who kissed his
# coursely to say something when she had to say to him. The countess
# were all sincerely attaining the matter with all shade of his
# word on the represents of her soul, and with which he came up from
# his, and well aware that he was stepping in the same time or to
# the steps. She did not heed herself to saying her as though to say, and
# to the carriage to his wife, he felt a significant of a chair. The
# southing had come to her. Stepan Arkadyevitch stord, she still seen that at
# that singer the disperity of the called with all the peasants and
# the countess of her face, which he saw how that the silence of all the
# country and haste atterested him off as it had been to the second
# child's coat and she had been that in a little chert with straight a
# best part in an other, and he could say nothi
